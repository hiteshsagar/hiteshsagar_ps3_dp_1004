# %% [markdown]
# # Problem Set 3

# %% [markdown]
# # Question 1
#
# Introduction:
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and
# materials.
#
# Occupations
#
# Step 1. Import the necessary libraries
#
# Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).
#
# Step 3. Assign it to a variable called users
#
# Step 4. Discover what is the mean age per occupation
#
# Step 5. Discover the Male ratio per occupation and sort it from the most to the least
#
# Step 6. For each occupation, calculate the minimum and maximum ages
#
# Step 7. For each combination of occupation and sex, calculate the mean age
#
# Step 8. For each occupation present the percentage of women and men

# %%
# Step 1: Import the necessary libraries
import pandas as pd

# %%
# Step 2: Import the dataset
data_url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user"

# %%
# Step 3: Data is now assigned to the 'users' variable
users = pd.read_csv(data_url, sep='|')
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
# Step 4: Mean age per occupation
mean_age_per_occupation = users.groupby('occupation')['age'].mean()
mean_age_per_occupation
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
# Step 5: Male ratio per occupation
def male_occupation_ratio(series):
    return (series == 'M').sum() / series.count()

# %%
male_ratio_per_occupation = users.groupby('occupation')['gender'].apply(male_occupation_ratio)
male_ratio_per_occupation = male_ratio_per_occupation.sort_values(ascending=False)
male_ratio_per_occupation
# Out:
# occupation
# doctor           1.000000
# engineer         0.970149
# technician       0.962963
# retired          0.928571
# programmer       0.909091
# executive        0.906250
# scientist        0.903226
# entertainment    0.888889
# lawyer           0.833333
# salesman         0.750000
# educator         0.726316
# student          0.693878
# other            0.657143
# marketing        0.615385
# writer           0.577778
# none             0.555556
# administrator    0.544304
# artist           0.535714
# librarian        0.431373
# healthcare       0.312500
# homemaker        0.142857
# Name: gender, dtype: float64

# %%
# Step 6: Minimum and maximum ages per occupation
min_age_per_occupation = users.groupby('occupation')['age'].min()
min_age_per_occupation
# Out:
# occupation
# administrator    21
# artist           19
# doctor           28
# educator         23
# engineer         22
# entertainment    15
# executive        22
# healthcare       22
# homemaker        20
# lawyer           21
# librarian        23
# marketing        24
# none             11
# other            13
# programmer       20
# retired          51
# salesman         18
# scientist        23
# student           7
# technician       21
# writer           18
# Name: age, dtype: int64

# %%
max_age_per_occupation = users.groupby('occupation')['age'].max()
max_age_per_occupation
# Out:
# occupation
# administrator    70
# artist           48
# doctor           64
# educator         63
# engineer         70
# entertainment    50
# executive        69
# healthcare       62
# homemaker        50
# lawyer           53
# librarian        69
# marketing        55
# none             55
# other            64
# programmer       63
# retired          73
# salesman         66
# scientist        55
# student          42
# technician       55
# writer           60
# Name: age, dtype: int64

# %%
# Step 7: Mean age per occupation and sex
mean_age_per_occupation_sex = users.groupby(['occupation', 'gender'])['age'].mean()
mean_age_per_occupation_sex
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %%
# Step 8: Percentage of women and men per occupation
def gender_occupation_percentage(series):
    total = series.count()
    return (series == 'F').sum() / total * 100, (series == 'M').sum() / total * 100

# %%
gender_percentage_per_occupation = users.groupby('occupation')['gender'].apply(gender_occupation_percentage)
female_percentage_per_occupation = gender_percentage_per_occupation.apply(lambda x: x[0])
male_percentage_per_occupation = gender_percentage_per_occupation.apply(lambda x: x[1])

# %%
female_percentage_per_occupation
# Out:
# occupation
# administrator    45.569620
# artist           46.428571
# doctor            0.000000
# educator         27.368421
# engineer          2.985075
# entertainment    11.111111
# executive         9.375000
# healthcare       68.750000
# homemaker        85.714286
# lawyer           16.666667
# librarian        56.862745
# marketing        38.461538
# none             44.444444
# other            34.285714
# programmer        9.090909
# retired           7.142857
# salesman         25.000000
# scientist         9.677419
# student          30.612245
# technician        3.703704
# writer           42.222222
# Name: gender, dtype: float64

# %%
male_percentage_per_occupation
# Out:
# occupation
# administrator     54.430380
# artist            53.571429
# doctor           100.000000
# educator          72.631579
# engineer          97.014925
# entertainment     88.888889
# executive         90.625000
# healthcare        31.250000
# homemaker         14.285714
# lawyer            83.333333
# librarian         43.137255
# marketing         61.538462
# none              55.555556
# other             65.714286
# programmer        90.909091
# retired           92.857143
# salesman          75.000000
# scientist         90.322581
# student           69.387755
# technician        96.296296
# writer            57.777778
# Name: gender, dtype: float64

# %% [markdown]
# # Question 2
#
# Euro Teams
#
# Step 1. Import the necessary libraries
#
# Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv)
#
# Step 3. Assign it to a variable called euro12
#
# Step 4. Select only the Goal column
#
# Step 5. How many team participated in the Euro2012?
#
# Step 6. What is the number of columns in the dataset?
#
# Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline
#
# Step 8. Sort the teams by Red Cards, then to Yellow Cards
#
# Step 9. Calculate the mean Yellow Cards given per Team
#
# Step 10. Filter teams that scored more than 6 goals
#
# Step 11. Select the teams that start with G
#
# Step 12. Select the first 7 columns
#
# Step 13. Select all columns except the last 3
#
# Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
# Step 1: Import the necessary libraries
import pandas as pd

# %%
# Step 2: Import the dataset
data_url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv"

# %%
# Step 3: Data is now assigned to the 'euro12' variable
euro12 = pd.read_csv(data_url)
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
# Step 4: Select only the Goal column
euro12['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
# Step 5: Number of teams participated
euro12['Team'].nunique()
# Out:
# 16

# %%
# Step 6: Number of columns in the dataset
euro12.shape[1]
# Out:
# 35

# %%
# Step 7: Create a dataframe with Team, Yellow Cards, and Red Cards columns
discipline = euro12[['Team', 'Yellow Cards', 'Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
# Step 8: Sort teams by Red Cards and then by Yellow Cards
discipline_sorted = discipline.sort_values(by=['Red Cards', 'Yellow Cards'], ascending=[False, False])
discipline_sorted
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %%
# Step 9: Calculate mean Yellow Cards per Team
round(discipline['Yellow Cards'].mean())
# Out:
# 7

# %%
# Step 10: Filter teams that scored more than 6 goals
euro12[euro12['Goals'] > 6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %%
# Step 11: Select teams that start with G
euro12[euro12['Team'].str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %%
# Step 12: Select the first 7 columns
euro12.iloc[:, :7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
# Step 13: Select all columns except the last 3
euro12.iloc[:, :-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
# Step 14: Select Shooting Accuracy from England, Italy, and Russia
euro12[euro12['Team'].isin(['England', 'Italy', 'Russia'])][['Team', 'Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# # Question 3
#
# Housing
#
# Step 1. Import the necessary libraries
#
# Step 2. Create 3 differents Series, each of length 100, as follows:
# * The first a random number from 1 to 4
# * The second a random number from 1 to 3
# * The third a random number from 10,000 to 30,000
#
# Step 3. Create a DataFrame by joinning the Series by column
#
# Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter
#
# Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'
#
# Step 6. Ops it seems it is going only until index 99. Is it true?
#
# Step 7. Reindex the DataFrame so it goes from 0 to 299

# %%
# Step 1: Import the necessary libraries
import pandas as pd
import numpy as np

# %%
# Step 2: Create 3 Series
series1 = pd.Series(np.random.randint(1, 5, size=100))
series2 = pd.Series(np.random.randint(1, 4, size=100))
series3 = pd.Series(np.random.randint(10000, 30001, size=100))

# %%
# Step 3: Create a DataFrame by joining the Series by column
data = pd.concat([series1, series2, series3], axis=1)
data
# Out:
#     0  1      2
# 0   4  1  28514
# 1   2  3  24306
# 2   4  3  10180
# 3   3  2  29093
# 4   1  3  29133
# .. .. ..    ...
# 95  4  3  19546
# 96  4  2  10984
# 97  2  3  15141
# 98  2  3  20502
# 99  4  1  22354
#
# [100 rows x 3 columns]

# %%
# Step 4: Change the column names
data.columns = ['bedrs', 'bathrs', 'price_sqr_meter']
data
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       4       1            28514
# 1       2       3            24306
# 2       4       3            10180
# 3       3       2            29093
# 4       1       3            29133
# ..    ...     ...              ...
# 95      4       3            19546
# 96      4       2            10984
# 97      2       3            15141
# 98      2       3            20502
# 99      4       1            22354
#
# [100 rows x 3 columns]

# %%
# Step 5: Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'
bigcolumn = pd.concat([series1, series2, series3], axis=0)
bigcolumn = bigcolumn.to_frame()
bigcolumn
# Out:
#         0
# 0       4
# 1       2
# 2       4
# 3       3
# 4       1
# ..    ...
# 95  19546
# 96  10984
# 97  15141
# 98  20502
# 99  22354
#
# [300 rows x 1 columns]

# %%
# Step 6: Check if the bigcolumn goes only until index 99
print(bigcolumn.index.max() == 99)
# Out:
# True

# %%
# Step 7: Reindex the DataFrame
bigcolumn.reset_index(drop=True, inplace=True)

# %% [markdown]
# # Question 4
#
# Wind Statistics
#
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise easier, in particular for the bonus question.
#
# You should be able to perform all of these operations without using a for loop or other looping construct.
#
# The data in 'wind.data' has the following format:
# ```
# Yr Mo Dy RPT VAL ROS KIL SHA BIR DUB CLA MUL CLO BEL MAL
# 61 1 1 15.04 14.96 13.17 9.29 NaN 9.87 13.67 10.25 10.83 12.58 18.50 15.04
# 61 1 2 14.71 NaN 10.83 6.50 12.62 7.67 11.50 10.04 9.79 9.67 17.54 13.83
# 61 1 3 18.50 16.88 12.33 10.13 11.17 6.17 11.25 NaN 8.50 7.67 12.75 12.71
# ```
#
# The first three columns are year, month, and day. The remaining 12 columns are
# average windspeeds in knots at 12 locations in Ireland on that day.
#
# Step 1. Import the necessary libraries
#
# Step 2. Import the dataset from the attached file wind.txt
#
# Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.
#
# Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.
#
# Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].
#
# Step 6. Compute how many values are missing for each location over the entire
# record. They should be ignored in all calculations below.
#
# Step 7. Compute how many non-missing values there are in total.
#
# Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
#
# A single number for the entire dataset.
#
# Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean
# windspeeds and standard deviations of the windspeeds at each location over all the days.
#
# A different set of numbers for each location.
#
# Step 10. Create a DataFrame called day_stats and calculate the min, max and mean
# windspeed and standard deviations of the windspeeds across all the locations at each day.
#
# A different set of numbers for each day.
#
# Step 11. Find the average windspeed in January for each location.
#
# Treat January 1961 and January 1962 both as January.
#
# Step 12. Downsample the record to a yearly frequency for each location.
#
# Step 13. Downsample the record to a monthly frequency for each location.
#
# Step 14. Downsample the record to a weekly frequency for each location.
#
# Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
# Step 1: Import the necessary libraries
import pandas as pd
import datetime

# %%
# Step 2: Import the dataset
data = pd.read_csv("wind.txt", delim_whitespace=True, parse_dates=[[0, 1, 2]])

# %%
# Step 3: Set datetime
data
# Out:
#        Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0    2061-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1    2061-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2    2061-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3    2061-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4    2061-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# 1      9.79   9.67  17.54  13.83
# ...

# %%
# Step 4: Function to fix the year 2061
def fix_year(x):
  year = x.year - 100 if x.year > 1989 else x.year
  return datetime.date(year, x.month, x.day)

# %%
data['Yr_Mo_Dy'] = data['Yr_Mo_Dy'].apply(fix_year)
data
# Out:
#         Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# ...

# %%
# Step 5: Convert the index to datetime64[ns]
data["Yr_Mo_Dy"] = pd.to_datetime(data["Yr_Mo_Dy"])
data = data.set_index('Yr_Mo_Dy')
data
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# Yr_Mo_Dy
# 1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04
# 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25
# 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50
# 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46
# 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58
#
#               CLO    BEL    MAL
# Yr_Mo_Dy
# ...

# %%
# Step 6: Count missing values for each location
data.isnull().sum()
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %%
# Step 7: Count non-missing values in total
data.notnull().sum()
# Out:
# RPT    6568
# VAL    6571
# ROS    6572
# KIL    6569
# SHA    6572
# BIR    6574
# DUB    6571
# CLA    6572
# MUL    6571
# CLO    6573
# BEL    6574
# MAL    6570
# dtype: int64

# %%
total_non_missing_values = data.count().sum()
total_non_missing_values
# Out:
# 78857

# %%
# Step 8: Calculate the mean windspeed over all locations and times
data.stack().mean()
# Out:
# 10.22788376428219

# %%
# Step 9: Calculate statistics for each location
data.describe()
# Out:
#                RPT          VAL          ROS          KIL          SHA  \
# count  6568.000000  6571.000000  6572.000000  6569.000000  6572.000000
# mean     12.362987    10.644314    11.660526     6.306468    10.455834
# std       5.618413     5.267356     5.008450     3.605811     4.936125
# min       0.670000     0.210000     1.500000     0.000000     0.130000
# 25%       8.120000     6.670000     8.000000     3.580000     6.750000
# 50%      11.710000    10.170000    10.920000     5.750000     9.960000
# 75%      15.920000    14.040000    14.670000     8.420000    13.540000
# max      35.800000    33.370000    33.840000    28.460000    37.540000
#
#                BIR          DUB          CLA          MUL          CLO  \
# count  6574.000000  6571.000000  6572.000000  6571.000000  6573.000000
# mean      7.092254     9.797343     8.495053     8.493590     8.707332
# std       3.968683     4.977555     4.499449     4.166872     4.503954
# ...

# %%
# Step 10: Calculate statistics for each day
day_stats = data.resample('D').agg(['min', 'max', 'mean', 'std'])
day_stats
# Out:
#               RPT                      VAL                      ROS         \
#               min    max   mean std    min    max   mean std    min    max
# Yr_Mo_Dy
# 1961-01-01  15.04  15.04  15.04 NaN  14.96  14.96  14.96 NaN  13.17  13.17
# 1961-01-02  14.71  14.71  14.71 NaN    NaN    NaN    NaN NaN  10.83  10.83
# 1961-01-03  18.50  18.50  18.50 NaN  16.88  16.88  16.88 NaN  12.33  12.33
# 1961-01-04  10.58  10.58  10.58 NaN   6.63   6.63   6.63 NaN  11.75  11.75
# 1961-01-05  13.33  13.33  13.33 NaN  13.25  13.25  13.25 NaN  11.42  11.42
# ...           ...    ...    ...  ..    ...    ...    ...  ..    ...    ...
# 1978-12-27  17.58  17.58  17.58 NaN  16.96  16.96  16.96 NaN  17.62  17.62
# 1978-12-28  13.21  13.21  13.21 NaN   5.46   5.46   5.46 NaN  13.46  13.46
# 1978-12-29  14.00  14.00  14.00 NaN  10.29  10.29  10.29 NaN  14.42  14.42
# 1978-12-30  18.50  18.50  18.50 NaN  14.04  14.04  14.04 NaN  21.29  21.29
# ...

# %%
day_stats = pd.DataFrame()
day_stats['min'] = data.min(axis = 1)
day_stats['max'] = data.max(axis = 1)
day_stats['mean'] = data.mean(axis = 1)
day_stats['std'] = data.std(axis = 1)

day_stats
# Out:
#              min    max       mean       std
# Yr_Mo_Dy
# 1961-01-01  9.29  18.50  13.018182  2.808875
# 1961-01-02  6.50  17.54  11.336364  3.188994
# 1961-01-03  6.17  18.50  11.641818  3.681912
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356
# ...          ...    ...        ...       ...
# 1978-12-27  8.08  40.08  16.708333  7.868076
# 1978-12-28  5.00  41.46  15.150000  9.687857
# 1978-12-29  8.71  29.58  14.890000  5.756836
# 1978-12-30  9.13  28.79  15.367500  5.540437
# 1978-12-31  9.59  27.29  15.402500  5.702483
#
# [6574 rows x 4 columns]

# %%
# Step 11: Average windspeed in January for each location
average_january_windspeed = data.loc[data.index.month == 1].mean()
average_january_windspeed
# Out:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %%
# Step 12: Downsample to yearly frequency
yearly_resampled = data.groupby(data.index.to_period('Y')).mean()
yearly_resampled
# Out:
#                 RPT        VAL        ROS       KIL        SHA       BIR  \
# Yr_Mo_Dy
# 1961      12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962      12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963      12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964      12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965      12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966      13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967      12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968      11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969      11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970      12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 1971      11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# 1972      12.463962  10.561311  12.058333  5.929699   9.430410  6.358825
# ...

# %%
# Step 13: Downsample to monthly frequency
monthly_resampled = data.groupby(data.index.to_period('M')).mean()
monthly_resampled
# Out:
#                 RPT        VAL        ROS       KIL        SHA        BIR  \
# Yr_Mo_Dy
# 1961-01   14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-02   16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03   10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04   10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05    9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
# ...             ...        ...        ...       ...        ...        ...
# 1978-08    9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09   10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10    9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11   16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# 1978-12   16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
# ...

# %%
# Step 14: Downsample to weekly frequency
weekly_resampled = data.groupby(data.index.to_period('W')).mean()
weekly_resampled
# Out:
#                              RPT        VAL        ROS        KIL        SHA  \
# Yr_Mo_Dy
# 1960-12-26/1961-01-01  15.040000  14.960000  13.170000   9.290000        NaN
# 1961-01-02/1961-01-08  13.541429  11.486667  10.487143   6.417143   9.474286
# 1961-01-09/1961-01-15  12.468571   8.967143  11.958571   4.630000   7.351429
# 1961-01-16/1961-01-22  13.204286   9.862857  12.982857   6.328571   8.966667
# 1961-01-23/1961-01-29  19.880000  16.141429  18.225714  12.720000  17.432857
# ...                          ...        ...        ...        ...        ...
# 1978-11-27/1978-12-03  14.934286  11.232857  13.941429   5.565714  10.215714
# 1978-12-04/1978-12-10  20.740000  19.190000  17.034286   9.777143  15.287143
# 1978-12-11/1978-12-17  16.758571  14.692857  14.987143   6.917143  11.397143
# 1978-12-18/1978-12-24  11.155714   8.008571  13.172857   4.004286   7.825714
# 1978-12-25/1978-12-31  14.951429  11.801429  16.035714   6.507143   9.660000
#
# ...

# %%
# Step 15: Calculate statistics for the first 52 weeks
weekly_stats = data.resample('W').agg(['min','max','mean','std'])
weekly_stats.loc[weekly_stats.index[1:53], "RPT":"MAL"]
# Out:
#               RPT                                VAL                    \
#               min    max       mean       std    min    max       mean
# Yr_Mo_Dy
# 1961-01-08  10.58  18.50  13.541429  2.631321   6.63  16.88  11.486667
# 1961-01-15   9.04  19.75  12.468571  3.555392   3.54  12.08   8.967143
# 1961-01-22   4.92  19.83  13.204286  5.337402   3.42  14.37   9.862857
# 1961-01-29  13.62  25.04  19.880000  4.619061   9.96  23.91  16.141429
# 1961-02-05  10.58  24.21  16.827143  5.251408   9.46  24.21  15.460000
# 1961-02-12  16.00  24.54  19.684286  3.587677  11.54  21.42  16.417143
# 1961-02-19   6.04  22.50  15.130000  5.064609  11.63  20.17  15.091429
# 1961-02-26   7.79  25.80  15.221429  7.020716   7.08  21.50  13.625714
# 1961-03-05  10.96  13.33  12.101429  0.997721   8.83  17.00  12.951429
# 1961-03-12   4.88  14.79   9.376667  3.732263   8.08  16.96  11.578571
# 1961-03-19   4.92  16.88  11.911429  3.860036   9.46  15.54  13.501429
# ...

# %% [markdown]
# # Question 5
#
# Step 1. Import the necessary libraries
#
# Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).
#
# Step 3. Assign it to a variable called chipo.
#
# Step 4. See the first 10 entries
#
# Step 5. What is the number of observations in the dataset?
#
# Step 6. What is the number of columns in the dataset?
#
# Step 7. Print the name of all the columns.
#
# Step 8. How is the dataset indexed?
#
# Step 9. Which was the most-ordered item?
#
# Step 10. For the most-ordered item, how many items were ordered?
#
# Step 11. What was the most ordered item in the choice_description column?
#
# Step 12. How many items were orderd in total?
#
# Step 13.
# * Turn the item price into a float
# * Check the item price type
# * Create a lambda function and change the type of item price
# * Check the item price type
#
# Step 14. How much was the revenue for the period in the dataset?
#
# Step 15. How many orders were made in the period?
#
# Step 16. What is the average revenue amount per order?
#
# Step 17. How many different items are sold?

# %%
# Step 1: Import the necessary libraries
import pandas as pd

# %%
# Step 2: Import the dataset
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"

# %%
# Step 3: Data is now assigned to the 'chipo' variable
chipo = pd.read_csv(url, sep='\t')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# Step 4: See the first 10 entries
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
# Step 5: Number of observations in the dataset
chipo.shape[0]
# Out:
# 4622

# %%
# Step 6: Number of columns in the dataset
chipo.shape[1]
# Out:
# 5

# %%
# Step 7: Print the name of all the columns
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
# Step 8: How is the dataset indexed?
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
# Step 9: Most-ordered item
most_ordered_item = chipo['item_name'].value_counts().idxmax()
most_ordered_item
# Out:
# 'Chicken Bowl'

# %%
# Step 10: Number of most-ordered item
chipo['item_name'].value_counts().max()
# Out:
# 726

# %%
# Step 11: Most ordered item in the choice_description column
chipo['choice_description'].value_counts().idxmax()
# Out:
# '[Diet Coke]'

# %%
# Step 12: Total number of items ordered
total_items_ordered = chipo['quantity'].sum()
total_items_ordered
# Out:
# 4972

# %%
# Step 13:
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x[1:]))

print(chipo['item_price'].dtype)
# Out:
# float64

# %%
# Step 14: Revenue for the period
revenue = (chipo['quantity'] * chipo['item_price']).sum()
revenue
# Out:
# 39237.02

# %%
# Step 15: Number of orders made
num_orders = chipo['order_id'].nunique()
num_orders
# Out:
# 1834

# %%
# Step 16: Average revenue amount per order
revenue / num_orders
# Out:
# 21.39423118865867

# %%
# Step 17: Number of different items sold
chipo['item_name'].nunique()
# Out:
# 50

# %% [markdown]
# # Question 6
#
# Create a line plot showing the number of marriages and divorces per capita in the U.S. between 1867 and 2014. Label both lines and show the legend.
#
# Don't forget to label your axes!

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset
data = pd.read_csv("us-marriages-divorces-1867-2014.csv")

# %%
# Calculate marriages and divorces per capita
data['Marriages_per_capita'] = data['Marriages'] / data['Population'] * 1000
data['Divorces_per_capita'] = data['Divorces'] / data['Population'] * 1000

# %%
# Create a figure and axis with larger font size and style
plt.figure(figsize=(12, 8))
plt.style.use('seaborn-darkgrid')

# Plotting
plt.plot(data['Year'], data['Marriages_per_capita'], label='Marriages per capita', linewidth=2)
plt.plot(data['Year'], data['Divorces_per_capita'], label='Divorces per capita', linewidth=2)

# Highlight interesting points
peak_marriage_year = data.loc[data['Marriages_per_capita'].idxmax()]['Year']
peak_divorce_year = data.loc[data['Divorces_per_capita'].idxmax()]['Year']

plt.scatter(peak_marriage_year, data['Marriages_per_capita'].max(), color='green', s=100, label='Peak Marriages')
plt.scatter(peak_divorce_year, data['Divorces_per_capita'].max(), color='red', s=100, label='Peak Divorces')

# Annotate the peak points
plt.annotate('Peak Marriages', xy=(peak_marriage_year, data['Marriages_per_capita'].max()), xytext=(peak_marriage_year + 10, data['Marriages_per_capita'].max() + 10),
             arrowprops=dict(facecolor='green', shrink=0.05), fontsize=10, color='green')
plt.annotate('Peak Divorces', xy=(peak_divorce_year, data['Divorces_per_capita'].max()), xytext=(peak_divorce_year - 30, data['Divorces_per_capita'].max() + 15),
             arrowprops=dict(facecolor='red', shrink=0.05), fontsize=10, color='red')

# Adding labels, title, legend, and grid
plt.xlabel('Year', fontsize=12)
plt.ylabel('Per Capita', fontsize=12)
plt.title('Marriages and Divorces per Capita in the U.S. (1867-2014)', fontsize=14)
plt.legend(fontsize=10)
plt.grid(alpha=0.5)

# Adding a background color for emphasis
plt.axvspan(peak_marriage_year - 10, peak_divorce_year + 10, facecolor='gray', alpha=0.1)

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Question 7
#
# Create a vertical bar chart comparing the number of marriages and divorces per
# capita in the U.S. between 1900, 1950, and 2000.
#
# Don't forget to label your axes!

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset
data = pd.read_csv("us-marriages-divorces-1867-2014.csv")

# %%
# Calculate marriages and divorces per capita
data['Marriages_per_capita'] = data['Marriages'] / data['Population'] * 1000
data['Divorces_per_capita'] = data['Divorces'] / data['Population'] * 1000

# %%
# Select data for the specified years
selected_years = [1900, 1950, 2000]
selected_data = data[data['Year'].isin(selected_years)]

# %%
# Calculate per capita values
data['Marriages_per_capita'] = data['Marriages'] / data['Population'] * 1000
data['Divorces_per_capita'] = data['Divorces'] / data['Population'] * 1000
selected_years = [1900, 1950, 2000]
selected_data = data[data['Year'].isin(selected_years)]

# Create a figure and axis
plt.figure(figsize=(10, 6))

# Plotting stacked bars with colors
plt.bar(selected_data['Year'], selected_data['Marriages_per_capita'], label='Marriages per capita', color='skyblue')
plt.bar(selected_data['Year'], selected_data['Divorces_per_capita'], label='Divorces per capita',
        bottom=selected_data['Marriages_per_capita'], color='salmon')

# Adding labels, title, and legend
plt.xlabel('Year')
plt.ylabel('Per Capita')
plt.title('Marriages and Divorces per Capita in the U.S. (1900, 1950, 2000)')
plt.legend()

# Adding a subtle grid
plt.grid(alpha=0.5, linestyle='--')


# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Question 8
#
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort the actors by their kill count and label each bar with the corresponding actor's name.
#
# Don't forget to label your axes!

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset
data = pd.read_csv("actor_kill_counts.csv")

# %%
# Sort the data by kill count in descending order
data = data.sort_values(by='Count', ascending=True)

# %%
import matplotlib.pyplot as plt

# Assuming 'data' is a DataFrame with columns 'Actor' and 'Count'

# Set up the figure with a specified size
plt.figure(figsize=(10, 6))

# Create horizontal bar chart
bars = plt.barh(data['Actor'], data['Count'])

# Add labels to the end of each bar indicating the kill count
for bar in bars:
    # Calculate the x-coordinate for the label by adding an offset to the bar's width
    label_x = bar.get_width() + 10
    # Calculate the y-coordinate for the label at the center of the bar's height
    label_y = bar.get_y() + bar.get_height() / 2
    # Convert the bar's width to an integer and display it as a label
    plt.text(label_x, label_y, str(int(bar.get_width())), va='center')

# Set labels, title, and grid
plt.xlabel('Kill Count')
plt.ylabel('Actor')
plt.title('Deadliest Actors in Hollywood')
plt.grid(axis='x')

# Display the plot
plt.show()

# %% [markdown]
# # Question 9
#
# Create a pie chart showing the fraction of all Roman Emperors that were
# assassinated.
#
#
# Make sure that the pie chart is an even circle, labels the categories, and shows the percentage breakdown of the categories.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset
data = pd.read_csv("roman-emperor-reigns.csv")

# %%
# Count the number of emperors that were assassinated
assassinated_count = data[data['Cause_of_Death'] == 'Assassinated'].shape[0]

# %%
# Count the number of emperors that were not assassinated
not_assassinated_count = data.shape[0] - assassinated_count

# %%
# Create a pie chart
labels = ['Assassinated', 'Not Assassinated']
sizes = [assassinated_count, not_assassinated_count]
colors = ['#FF9999', '#99FF55']
explode = (0.1, 0)

plt.figure(figsize=(6, 6))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')

plt.title('Fraction of Roman Emperors that were Assassinated')
plt.show()

# %% [markdown]
# # Question 10
#
# Create a scatter plot showing the relationship between the total revenue earned by arcades and the number of Computer Science PhDs awarded in the U.S. between
# 2000 and 2009.
#
# Don't forget to label your axes!
#
# Color each dot according to its year.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset
data = pd.read_csv("arcade-revenue-vs-cs-doctorates.csv")

# %%
# Extract data
years = data['Year']
revenue = data['Total Arcade Revenue (billions)']
doctorates = data['Computer Science Doctorates Awarded (US)']

# %%
# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(revenue, doctorates, c=years, cmap='turbo', s=80, alpha=0.8)
plt.colorbar(label='Year')
plt.xlabel('Total Arcade Revenue (billions)')
plt.ylabel('Computer Science Doctorates Awarded (US)')
plt.title('Relationship between Arcade Revenue and Computer Science Doctorates (2000-2009)')
plt.grid(True)
plt.show()
